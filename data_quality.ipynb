# %%
# Importando as bibliotecas
import pandas as pd
from data_quality_module import DataQualitys

# Carregando o dataset
df = pd.read_csv('mal_top2000_anime.csv')

# Inicializando a análise com um limite de 15 colunas para deixar os graficos mais légiveis
analysis = DataQualitys(df,max_columns=15)

# Gera um relatório completo
analysis.full_report()
# Out:
# Contagem de nulos:
#  Unnamed: 0             0
# Name                   0
# Type                   0
# Score                  0
# Score Rank             0
# Popularity Rank        0
# Air Date               0
# Studio                 0
# Num. of episodes       0
# Genres                 0
# Theme(s)               0
# Demographic         1027
# dtype: int64
#
# Contagem de valores únicos:
#  Unnamed: 0          2000
# Name                1999
# Type                   6
# Score                157
# Score Rank          1994
# Popularity Rank     1975
# Air Date            1832
# Studio               273
# Num. of episodes     113
# Genres               370
# Theme(s)             322
# Demographic            5
# dtype: int64
#
# COLUNA = Name
#                                                    Name  count
# 0                        Fugou Keiji: Balance:Unlimited      2
# 1     Re:Zero kara Hajimeru Isekai Seikatsu - Hyouke...      1
# ...
