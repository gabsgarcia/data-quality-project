# %%
# Importando as bibliotecas
import pandas as pd
from data_quality_module import DataQualitys

# Carregando o dataset (substitua pelo seu arquivo)
df = pd.read_csv('penguins.csv')

# Inicializando a análise
analysis = DataQualitys(df)

# Gera um relatório completo
analysis.full_report()
# Out:
# Contagem de nulos:
#  species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64
#
# Contagem de valores únicos:
#  species                3
# island                 3
# bill_length_mm       164
# bill_depth_mm         80
# flipper_length_mm     55
# body_mass_g           94
# sex                    2
# dtype: int64
# Value counts for species:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64
#
# Value counts for island:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64
#
# Value counts for sex:
# sex
# MALE      168
# FEMALE    165
# Name: count, dtype: int64
#
#
# Contagem de valores categoricos: None
#
# Resumo estatístico de colunas numéricas:
#         bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# ...
